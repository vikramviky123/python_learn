# %% [markdown]
# #Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
3+2
# Out:
# 5

# %%
10-5
# Out:
# 5

# %%
10*5
# Out:
# 50

# %%
10**2
# Out:
# 100

# %%
10/5
# Out:
# 2.0

# %%
10%5
# Out:
# 0

# %%
10%3
# Out:
# 1

# %%
10//5
# Out:
# 2

# %% [markdown]
# #Working with String Formatting

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fname = "Vikram"
lname = 7
myStr = "Code of %s is %d" % (fname, lname)
print(myStr)
# Out:
# Code of Vikram is 7

# %%
myString = "Scaler"
length = 20
myStr = "Dynamically Right Aligned String is: {:>{}}.".format(myString, length)
print(myStr)
myStr = "Dynamically Center Aligned String is: {:^{}}.".format(myString, length)
print(myStr)
myStr = "Dynamically Padded String with input on left is: {:*<{}}.".format(myString, length)
print(myStr)
myStr = "Dynamically Padded string with input on right is: {:*>{}}.".format(myString, length)
print(myStr)
myStr = "Dynamically Padded string with input on center is: {:*^{}}.".format(myString, length)
print(myStr)
myStr = "Dynamically truncated String with output length 3 is: {:.{}}.".format(myString, 3)
print(myStr)
# Out:
# Dynamically Right Aligned String is:               Scaler.
# Dynamically Center Aligned String is:        Scaler       .
# Dynamically Padded String with input on left is: Scaler**************.
# Dynamically Padded string with input on right is: **************Scaler.
# Dynamically Padded string with input on center is: *******Scaler*******.
# Dynamically truncated String with output length 3 is: Sca.

# %%
import datetime 
#datetime formatting 
date=datetime.datetime.now() 
print("It's now:{:%d/%m/%Y %H:%M:%S:%p}".format(date))
# Out:
# It's now:30/07/2023 10:05:39:AM

# %%
def print_full_name(first, last):
    # Write your code here
    zz =  f"Hello {first} {last}! You just delved into python."
    return zz

if __name__ == '__main__':
    first_name = "Vikram"
    last_name = "Reddy"
    print_full_name(first_name, last_name)

# %%
def count_substring(string, sub_string):
    l = len(string) - len(sub_string) + 1
    count = 0
    for i in range(l):
        xx = string[i:i+2]
        if  xx == sub_string:
            count+=1
    return count
string = "ThIsisCoNfUsInG"
sub_string = "is"

print(count_substring(string, sub_string))
# Out:
# 1

# %%
stri = "AABCAAADA"
length = len(stri)

for i in range(0,length,3):
    nw_str = stri[i:i+3]
    nw_lst = list(nw_str)
    fin_lst = []
    for j in range(3):
        if nw_lst[j] not in fin_lst:
            fin_lst.append(nw_lst[j])
    fin_str = "".join(fin_lst)
    print(fin_str)
# Out:
# AB
# CA
# AD

# %%
stri = "AABCAAADA"
length = len(stri)

for i in range(0,length,3):
    nw_str = stri[i:i+3]
    print(list(nw_str))
    print(set(list(nw_str)))
    nw_lst = list(set(list(nw_str)))
    fin_str = "".join(nw_lst)
# Out:
# ['A', 'A', 'B']
# {'B', 'A'}
# ['C', 'A', 'A']
# {'A', 'C'}
# ['A', 'D', 'A']
# {'A', 'D'}

# %%
s = "..."

# %%
lst = []
consonant_lst = []
vowel_lst = []

vowels = list("AEIOU")

length = len(s)

for i in range(length):
    for j in range(1,length-i+1,1):
        if s[i] in vowels:
            vowel_lst.append(s[i:i+j])
        else:
            consonant_lst.append(s[i:i+j])
            
if len(consonant_lst)>len(vowel_lst):
    print("STUART",len(consonant_lst))
elif len(consonant_lst)<len(vowel_lst):
    print("KEVIN",len(vowel_lst))
elif len(consonant_lst)==len(vowel_lst):
    print("DRAW")

# %%
round(56.7)
# Out:
# 57

# %%
round(56.3)
# Out:
# 56

# %%
print("52"+chr(176))
# Out:
# 52°
